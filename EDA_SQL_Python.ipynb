# %% [markdown]
# ## SQL - Python

# %% [markdown]
# #### Python - IBM DB2 Database Connection

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://ssg43466:9hp%404blvtbwbrgft@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Out:
# 'Connected: ssg43466@BLUDB'

# %% [markdown]
# ##### Query the database system catalog to retrieve table metadata

# %%
# %%sql
# SELECT TABSCHEMA, TABNAME, CREATE_TIME
# FROM syscat.tables
# where tabschema = 'SSG43466';
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('SSG43466', 'SCHOOLS', datetime.datetime(2019, 12, 10, 14, 7, 5, 459400)),
#  ('SSG43466', 'JOB_HISTORY', datetime.datetime(2019, 12, 5, 16, 14, 54, 355546)),
#  ('SSG43466', 'JOBS', datetime.datetime(2019, 12, 5, 16, 14, 54, 544356)),
#  ('SSG43466', 'DEPARTMENTS', datetime.datetime(2019, 12, 5, 16, 14, 54, 748433)),
#  ('SSG43466', 'LOCATIONS', datetime.datetime(2019, 12, 5, 16, 14, 54, 930600)),
#  ('SSG43466', 'EMPLOYEES', datetime.datetime(2019, 12, 5, 16, 14, 53, 981002)),
#  ('SSG43466', 'PETSALE', datetime.datetime(2019, 12, 6, 11, 13, 7, 351686)),
#  ('SSG43466', 'INSTRUCTOR', datetime.datetime(2019, 12, 7, 13, 17, 40, 24160)),
#  ('SSG43466', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2019, 12, 8, 3, 23, 12, 57104)),
#  ('SSG43466', 'CHICAGO_DATA', datetime.datetime(2019, 12, 10, 4, 41, 11, 157937))]

# %% [markdown]
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# %%sql SELECT count(*) FROM syscat.COLUMNS
# where tabname = 'SCHOOLS';
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('78'),)]

# %% [markdown]
# ##### Retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# %%sql select COLNAME, TYPENAME, LENGTH
# from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('School_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 65),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Street_Address', 'VARCHAR', 30),
#  ('City', 'VARCHAR', 7),
#  ('State', 'VARCHAR', 2),
#  ('Link', 'VARCHAR', 78),
#  ('Network_Manager', 'VARCHAR', 40),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Track_Schedule', 'VARCHAR', 12),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('Safety_Icon', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('Family_Involvement_Icon', 'VARCHAR', 11),
#  ('Family_Involvement_Score', 'VARCHAR', 3),
#  ('Environment_Icon', 'VARCHAR', 11),
#  ('Environment_Score', 'SMALLINT', 2),
#  ('Instruction_Icon', 'VARCHAR', 11),
#  ('Instruction_Score', 'SMALLINT', 2),
# ...

# %% [markdown]
# ##### How many Elementary Schools are in the dataset?

# %%
# %sql SELECT * FROM SCHOOLS LIMIT 2;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# ...

# %%
# %sql SELECT DISTINCT ("Elementary, Middle, or High School") from SCHOOLS;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('ES',), ('HS',), ('MS',)]

# %%
# %sql SELECT COUNT(*) FROM SCHOOLS WHERE ("Elementary, Middle, or High School") = 'ES' ;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('462'),)]

# %% [markdown]
# ##### What is the highest Safety Score?

# %%
# %sql SELECT MAX(safety_score) FROM SCHOOLS;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(99,)]

# %%
# %%sql
# SELECT Name_of_School,Safety_Score FROM SCHOOLS
# WHERE Safety_Score = (SELECT MAX(Safety_Score) FROM SCHOOLS);
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Northside Learning Center High School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
#  ('Talman Elementary School', 99),
# ...

# %% [markdown]
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %%sql
#
# SELECT Name_of_School, Average_Student_Attendance FROM SCHOOLS
# ORDER BY AVERAGE_STUDENT_ATTENDANCE DESC LIMIT 10;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Velma F Thomas Early Childhood Center', None),
#  ('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%')]

# %% [markdown]
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance.

# %%
# %%sql
#
# SELECT Name_of_School, Average_Student_Attendance FROM SCHOOLS
# ORDER BY AVERAGE_STUDENT_ATTENDANCE LIMIT 5;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %%sql
#
# SELECT Name_of_School, REPLACE (Average_Student_Attendance, '%', '')as Average_Student_Attendance FROM SCHOOLS
# ORDER BY AVERAGE_STUDENT_ATTENDANCE LIMIT 5;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# ##### which Schools have Average Student Attendance lower than 70%?

# %%
# %%sql
# SELECT Name_of_School, Average_Student_Attendance FROM SCHOOLS
# where (REPLACE(AVERAGE_STUDENT_ATTENDANCE, '%', '') < 70)
# ORDER BY Average_Student_Attendance;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %% [markdown]
# ##### Get the total College Enrollment for each Community Area

# %%
# %%sql
#
# SELECT SUM("COLLEGE_ENROLLMENT") AS TOTAL_ENROLL, COMMUNITY_AREA_NAME
# from SCHOOLS GROUP BY COMMUNITY_AREA_NAME;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(6864, 'ALBANY PARK'),
#  (4823, 'ARCHER HEIGHTS'),
#  (1458, 'ARMOUR SQUARE'),
#  (6483, 'ASHBURN'),
#  (4175, 'AUBURN GRESHAM'),
#  (10933, 'AUSTIN'),
#  (1522, 'AVALON PARK'),
#  (3640, 'AVONDALE'),
#  (14386, 'BELMONT CRAGIN'),
#  (1636, 'BEVERLY'),
#  (3167, 'BRIDGEPORT'),
#  (9647, 'BRIGHTON PARK'),
#  (549, 'BURNSIDE'),
#  (1568, 'CALUMET HEIGHTS'),
#  (5042, 'CHATHAM'),
#  (7086, 'CHICAGO LAWN'),
#  (2085, 'CLEARING'),
#  (4670, 'DOUGLAS'),
#  (4568, 'DUNNING'),
#  (5337, 'EAST GARFIELD PARK'),
#  (5305, 'EAST SIDE'),
#  (4600, 'EDGEWATER'),
#  (910, 'EDISON PARK'),
#  (6832, 'ENGLEWOOD'),
#  (1431, 'FOREST GLEN'),
#  (531, 'FULLER PARK'),
#  (9915, 'GAGE PARK'),
#  (4552, 'GARFIELD RIDGE'),
#  (2809, 'GRAND BOULEVARD'),
#  (4051, 'GREATER GRAND CROSSING'),
#  (963, 'HEGEWISCH'),
#  (3975, 'HERMOSA'),
#  (8620, 'HUMBOLDT PARK'),
#  (1930, 'HYDE PARK'),
# ...

# %% [markdown]
# ##### Get the 5 Community Areas with the least total College Enrollment sorted in ascending order

# %%
# %%sql
#
# SELECT SUM("COLLEGE_ENROLLMENT") AS TOTAL_ENROLL, COMMUNITY_AREA_NAME
# from SCHOOLS GROUP BY COMMUNITY_AREA_NAME ORDER BY TOTAL_ENROLL LIMIT 5;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(140, 'OAKLAND'),
#  (531, 'FULLER PARK'),
#  (549, 'BURNSIDE'),
#  (786, 'OHARE'),
#  (871, 'LOOP')]

# %% [markdown]
# ##### Get the hardship index for the community area which has College Enrollment of 4638

# %% [markdown]
# ###### Hardship index from chicago_socioeconomic_data table

# %%
# %%sql
#
# SELECT hardship_index FROM chicago_socioeconomic_data CD, SCHOOLS S
# WHERE CD.ca = S.community_area_number and college_enrollment = 4368;
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(6.0,)]

# %% [markdown]
# ##### Get the hardship index for the community area which has the highest value for College Enrollment

# %%
# %%sql
#
# select ca, community_area_name, hardship_index from chicago_socioeconomic_data
#    where ca in (select community_area_number from schools WHERE college_enrollment = (SELECT MAX(college_enrollment) FROM SCHOOLS));
# Out:
#  * ibm_db_sa://ssg43466:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(5.0, 'North Center', 6.0)]
